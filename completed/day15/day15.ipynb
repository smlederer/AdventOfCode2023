# %%
import sys
import os

__file__ = 'helper_funcs.py'
file_path = os.path.abspath(os.path.join(os.path.dirname( __file__ ), '..'))
sys.path.append(file_path)

import helper_funcs as hf

# %%
# raw_input = 'rn=1,cm-,qp=3,cm=2,qp-,pc=4,ot=9,ab=5,pc-,pc=6,ot=7'


raw_input = hf.read_file('input.txt')
mod_input = raw_input.strip().split(',')


def hashit(string:str) -> int:
    total = 0
    for i in string:
        total = 17*(total + ord(i))
        total = total%256
    return total

tot = 0
for i in mod_input:
    tot += hashit(i)
print(tot)
# Out:
# 503154

# %%
mod_input
# Out:
# ['rn=1',
#  'cm-',
#  'qp=3',
#  'cm=2',
#  'qp-',
#  'pc=4',
#  'ot=9',
#  'ab=5',
#  'pc-',
#  'pc=6',
#  'ot=7']

# %%
#part 2
def search_box(box:list,key:str)->int:
    #box is [{a:1},{b,2}...] structure
    indexes = [n for n,i in enumerate(box) if str(list(i.keys())[0])==key]
    return indexes

boxes = {}
for i in range(0,257):
    boxes.setdefault(i,[])

input_2 = [i.replace('-','=').split('=') for i in mod_input]
for i in input_2:
    index = hashit(i[0])
    box = boxes[hashit(i[0])]
    #check if it already exists
    find = search_box(box,i[0])
    if len(find)>=1:
        if i[1].isdigit():
            boxes[index][find[0]] = {i[0]:i[1]}
        else:
            boxes[index].pop(find[0])
    if len(find)<1:
        if i[1].isdigit():
            boxes[index].append({i[0]:i[1]})
print(boxes)
# Out:
# {0: [{'cm': '5'}], 1: [], 2: [{'vfprd': '5'}], 3: [{'xhs': '5'}], 4: [{'jnbfd': '3'}], 5: [{'rhpxs': '3'}], 6: [{'spc': '7'}], 7: [], 8: [], 9: [], 10: [], 11: [{'mvx': '3'}], 12: [], 13: [{'vct': '4'}], 14: [{'tz': '5'}, {'fh': '5'}], 15: [], 16: [], 17: [{'bxg': '3'}], 18: [], 19: [{'glp': '8'}, {'jfs': '9'}, {'lfcfh': '6'}], 20: [], 21: [{'dqdl': '6'}], 22: [{'tnt': '8'}], 23: [{'mj': '6'}], 24: [{'bbt': '1'}], 25: [{'kn': '4'}], 26: [], 27: [{'znqb': '8'}, {'kjgmr': '5'}, {'xs': '5'}], 28: [], 29: [{'mxrf': '4'}, {'zrvk': '8'}], 30: [], 31: [], 32: [{'nqq': '2'}], 33: [], 34: [], 35: [{'hkp': '7'}, {'ldc': '6'}, {'bq': '6'}], 36: [{'pt': '6'}, {'jgc': '3'}], 37: [{'lmdx': '3'}, {'gzt': '1'}], 38: [], 39: [], 40: [{'mk': '4'}], 41: [{'lm': '1'}, {'nnlnc': '5'}], 42: [{'bbf': '5'}], 43: [{'jq': '7'}], 44: [{'vbhvv': '4'}], 45: [{'vbjch': '6'}], 46: [{'vx': '5'}], 47: [{'qmq': '3'}], 48: [], 49: [], 50: [{'zhp': '3'}, {'mrs': '1'}], 51: [{'rq': '3'}], 52: [{'ldd': '2'}, {'tcm': '6'}
# ...

# %%
def focal_len_calc(boxes:dict)->int:
    total = 0
    for i in boxes.items():
        for n,j in enumerate(i[1]):
            print(j)
            total += (i[0]+1)*(n+1)*(int(list(j.values())[0]))
            
    return total
focal_len_calc(boxes)
# Out:
# {'cm': '5'}
# {'vfprd': '5'}
# {'xhs': '5'}
# {'jnbfd': '3'}
# {'rhpxs': '3'}
# {'spc': '7'}
# {'mvx': '3'}
# {'vct': '4'}
# {'tz': '5'}
# {'fh': '5'}
# {'bxg': '3'}
# {'glp': '8'}
# {'jfs': '9'}
# {'lfcfh': '6'}
# {'dqdl': '6'}
# {'tnt': '8'}
# {'mj': '6'}
# {'bbt': '1'}
# {'kn': '4'}
# {'znqb': '8'}
# {'kjgmr': '5'}
# {'xs': '5'}
# {'mxrf': '4'}
# {'zrvk': '8'}
# {'nqq': '2'}
# {'hkp': '7'}
# {'ldc': '6'}
# {'bq': '6'}
# {'pt': '6'}
# {'jgc': '3'}
# {'lmdx': '3'}
# {'gzt': '1'}
# {'mk': '4'}
# {'lm': '1'}
# {'nnlnc': '5'}
# {'bbf': '5'}
# {'jq': '7'}
# {'vbhvv': '4'}
# {'vbjch': '6'}
# {'vx': '5'}
# {'qmq': '3'}
# {'zhp': '3'}
# {'mrs': '1'}
# {'rq': '3'}
# {'ldd': '2'}
# {'tcm': '6'}
# {'bc': '6'}
# {'hjs': '2'}
# {'zxcq': '2'}
# {'rrt': '5'}
# {'kpn': '7'}
# {'tlk': '9'}
# {'csdjh': '9'}
# {'jc': '6'}
# {'psddr': '9'}
# {'hv': '3'}
# {'vxfgd': '7'}
# {'fz': '8'}
# {'ftf': '9'}
# {'tn': '7'}
# {'sp': '7'}
# {'rr': '9'}
# {'xhmg': '3'}
# {'zhb': '8'}
# {'cfl': '1'}
# {'hjxk': '7'}
# ...
